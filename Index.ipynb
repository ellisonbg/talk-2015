# %% [markdown]
# ### Project Jupyter

# %%
from IPython.display import Image
Image("images/jupyter_logo.png", width=400)

# %% [markdown]
# # Outline

# %% [markdown]
# ## Outline
# * [Computational Narratives](Computational Narratives.ipynb)
# * [Notebook Tour](Notebook Tour.ipynb)
# * [Bash Examples](Bash Examples.ipynb)
# * [Interaction](Interaction.ipynb)

# %% [markdown]
# ## Jupyter Links
# * [Temporary Notebook](http://tmpnb.org)
# * [jupyter.org](http://jupyter.org)

# %% [markdown]
# ## Sample Notebooks
# * Google [deepdream](https://github.com/google/deepdream/blob/master/dream.ipynb)
# * Nasa [PyAMPR](https://github.com/nasa/PyAMPR/blob/master/notebooks/PyAMPR_Demo.ipynb)
# * Bloomberg [Notebooks](https://github.com/bloomberg/bqplot)
# * IBM [Spark](https://github.com/ibm-cds-labs/spark.samples/blob/master/streaming-twitter/notebook/Twitter%20%2B%20Watson%20Tone%20Analyzer%20Part%201.ipynb)
# * Buzzfeed [Data Science](https://github.com/BuzzFeedNews/2014-08-st-louis-county-segregation/blob/master/notebooks/segregation-analysis.ipynb)
